# %% [markdown]
# <h1><b>Estatística Descritiva</b></h1>
# <h2><b>O que é a estatística?</b></h2>
# <hr>
#
# Estatística é algo que existe há alguns milênios e que por muito tempo foi utilizada para fins tributários e militares nas civilizações antigas como no Egito, Babilônia e China. Contudo, o nome "Estatística" não foi algo tão antigo assim, já que esse nome deriva do latim <i>"Status"</i> e foi utilizado por um historiador alemão conhecido pelo nome de Gottfried Achenwall que cunhou esse termo em 1749 para se referir às análises qualitativas e quantitativas das civilizações antigas para coleta de informações sobre a população, sendo essas análises realizadas visando a priori aplicações tributárias e também para fins militares. Um exemplo disto era o recenseamento ocorrido em Roma de 5 em 5 anos para coleta de informações de sua população para propósitos militares, tributários e de classificação social.
#
# Com esta breve apresentação da história da estatística passamos para a apresentação de alguns conceitos que serão importante termos conhecimento para dar segmento no aprendizado estatístico. Sejam bem-vindos a trilha do Runemaru, mas podem me chamar de Rune! 😉

# %% [markdown]
# <b><h2>Conceitos da estatística</h2></b>
#
# * <b>Parâmetro:</b> O parâmetro é uma medida númerica que descreve uma característica da população completa. Contudo, por raramente trabalharmos com populações inteiras, os valores são desconhecidos e passam por estimação. Dentro dessa medida compreendemos a média, desvio padrão e proporção daquele conjunto populacional.
# * <b>estatística:</b> Apesar de ser confuso, quando utilizado em minúsculo refere-se a um tipo de medida. E basicamente a estatística é uma medida calculada exclusivamente de dados amostrais, e representa o que conseguimos observar e calcular de forma concreta.
# * <b>Estimador:</b>  O estimador é a fórmula utilizada para calcular a estatística que nos auxilia na aproximação do parâmetro. Como o cálculo da média, obtenção de mediana, moda, proporção, variância, desvio padrão, dentre outros.
#
# * <b>População:</b> É o total de observações/indivíduos relacionados a uma determinada característica.
# * <b>Amostragem:</b> É o processo de seleção de observações de uma população que visa criar uma amostra.
# * <b>Amostra:</b> Representa uma parcela da população.
#
# <hr>
#
# * <b>Variável:</b> Pode ser dito como um elemento que fora observado dentro de um conjunto de outros elementos sejam númericos ou não e que possui suas próprias características e atributos dos quais descrevem o mesmo. Estas variáveis na estatística possuem duas categorias e quatro subcategorias ao todo que serão aprofundadas logo em seguida, são estas:
#     * <b>Variáveis quantitativas:</b> Quando falamos de variáveis quantitativas, falamos de algo que pode ser mensurado ou enumerado de alguma forma. E é claro que quando falamos sobre enumerar de alguma forma tudo vai depender do modelo solicitado pela regra do negócio imposto por determinada questão, e falando em quantitativa, temos dois tipos assim como na qualitativa, são estes:
#         * <b>Discreta:</b> Variáveis que podem ser contadas sem necessidade de mensuração como por exemplo quantos carros uma pessoa comprou no último ano, ou então quantas peças de roupa ela tem., A variável discreta é representada por números inteiros.
#         * <b>Contínua:</b> Essa variável contínua por sua vez é tudo aquilo que é número, contudo há necessidade de mensurar seu valor de alguma forma. Como por exemplo, para sabermos o peso de alguém precisamos medir! E o peso pode ser 65KG como pode ser 65,45, assim como pode ser também 65,4556. Logo elementos como a velocidade de um carro, temperatura, peso e altura são considerados como variáveis contínuas. Essas variáveis por sua vez podem ser determinadas até mesmo por decimais e frações.
# * <b>Variáveis qualitativas:</b>  Quando falamos de variáveis qualitativas, falamos de atributos não numéricos, e dentro da qualitativa temos duas características que nos auxiliam a entender os dados de maneira mais profunda, são elas:
#     * <b>Ordinal:</b> Os atributos que se encaixam como ordinais conseguem reter uma ordem em específico, como os dias da semana ou grau de instrução escolar.
#     * <b>Nominal:</b> Já os atributos nominais não se encaixam em ordem alguma, e para entender melhor sobre as nominais podemos mencionar exemplos como; a cor dos olhos, grupo sanguíneo e até mesmo gênero. Já que eles não tem uma ordem de precedência como por exemplo, o primeiro e segundo ano escolar.
#     * <b>É sempre importante ressaltar que podemos transformar variáveis qualitativas em quantitativas, contudo varia de caso a caso.</b>
#
# Outro ponto interessante sobre as variáveis é que elas podem ser uni/bi/pluridimensionais. Ou seja, podem guardar uma única informação sobre uma característica, duas informações como idade e renda de trabalhadores, ou idade, altura e peso de um grupo de alunos.
# <hr>
#
# <b><h2>Medidas de tendência central e dispersão</h2></b>
#
# Começando por medidas de tendência central, falamos da apresentação dos valores centrais daquele conjunto de dados, os estimadores mais utilizados neste tópico são a média (aritmética, ponderada, geométrica), mediana e moda. Contudo, ao estudar variabilidade também temos, por exemplo a amplitude, desvio padrão e variância. Abaixo temos as fórmulas para a:
#
# **Média Aritmética:** Geralmente os dados seguem uma distribuição normal (formato de "sino"). Quando os dadods tem essas características o cálculo da média consegue representar perfeitamente o centro destes dados, contudo pode ser diretamente impactada quando há presença de outliers e inliers. Como representação disto podemos tirar a média aritmética de 1 a 10, que irá resultar em 5,5, contudo se adicionarmos o número 50 ao final deste conjunto, a média será 9,55. E por conta disto ela passa a não mais representar da melhor forma aquele conjunto.
#
# media(X)= \mu =\dfrac{1}{n}\sum_{i=1}^n x_i
#
#
# **Média ponderada:** A diferença entre a média aritmética e a ponderada está nos pesos que cada variável ali presente possui. Por exemplo se fossemos tirar a média entre valores monetários distintos. O dólar terá um peso diferente do real, assim como o rel terá um peso diferente do dólar.
#
# \bar{x} = \frac{\sum_{i=1}^{n} w_i x_i}{\sum_{i=1}^{n} w_i}
#
# **Mediana:** A mediana é uma medida que serve para localizar o centro da distribuição dos dados, sendo que existe fórmula para quando o tamanho de observações do conjunto for par ou ímpar, contudo antes de utilizar a medida é necessário ordenar os dados em rol de forma crescente ou decrescente. Quando o total de observações for par, a mediana será a média entre os dois valores centrais, enquanto ímpar será o valor central.
# \begin{align}
# \text{mediana}(x) = \left\{
# \begin{array}{cl}
# x_{(\frac{n+1}{2})} &  \text{ se }
#     n \text{ for ímpar} \\
# \frac{1}{2}[x_{(\frac{n}{2})}+x_{(\frac{n}{2}+1)}] &  \text{ se }
#     n \text{ for par}
# \end{array}
# \right.
# \end{align}
#
# **Moda:** Apesar de não possuir uma fórmula matemática, a moda é basicamente o valor que mais se repete dentro daquela característica ou conjunto númerico, e é sempre importante ressaltar que um conjunto pode ser bimodal, trimodal ou multiimodal
#
#
# Pontos interessantes de trazer é que quando a distribuição é simétrica, pois a média e mediana coincidem. Contudo, diferente da média que é influenciável por outliers e inliers, a mediana não é tão sensível. Então, quando há assimetria nos dados temos o seguinte exemplo:
# ![image.png](attachment:image.png)
# <hr>
#
# <b><h2>Medidas de Dispersão</h2></b>
#
# Então chegamos a medida de dispersão, que diferente da outra que focava em localizar o centro de uma distribuição de dados, irá medir a variabilidade (dispersão) presente naquele conjunto de dados, as medidas de dispersão são utilizadas para entender o grau de variabilidade presente no entorno da média aritmética, permitindo que consigamos entender a representatividade daquela média e também o nível de heterogeneidade ou homogeneidade daquele conjunto.
#
# **Variância:** A variância pode ser obtida a partir da soma dos quadrados dos desvios das observações de uma determinada amostra ou população, com isto caso a variância venha ser populacional é dividido pelo total de desvios, e caso amostral, dividido pelo total de desvios menos um.
#
# ![image-2.png](attachment:image-2.png)
#
#
# **Desvio-padrão:** O desvio-padrão é obtido a partir da raiz quadrada da variância.
#
# ![image-4.png](attachment:image-4.png)
#
# **Coeficiente de variação:**
#
# O coeficiente da variação serve para realizar medidas relativas de dispersão daquele conjunto, para calcular ele dividimos o desvio padrão pela média e então multiplicamos por 100 para tornar o valor percentual. Com isto, conseguimos saber a variabilidade da média de séries distintas. Agora de acordo com o resultado como sei o quão disperso é aquele conjunto? Simples.
# * Baixa dispersão: Coeficiente de variação <= 15%
# * Média dispersão: Coeficiente de variação entre 16% e 29%
# * Alta dispersão: Coeficiente de variação >= 30%
#
# <hr>

# %% [markdown]
# <center><b><h2>Conceitos fundamentais sobre a Amostragem</h2></b><center>
#
# Aqui irei apresentar vários tipos de amostragem, compreender e aprender suas características de formação, com isto podemos começar por falar:
#
# * **Não probabilística:**
# * **Acidental ou conveniência:**
# * **Intencional:**
# * **Quotas ou proporcional:**
# * **Desproporcional:**
# * **Probabilística:**
# * **Aleatória Simples:**
# * **Aleatória Estratificada:**
# * **Conglomerado:**

# %% [markdown]
# <b><h2>Conceitos de Probabilidade & Probabilidade</h2></b>
#
#
# * <b>Probabilidade:</b> É uma medida númerica que visa quantificar a incerteza de um evento aleatório ocorrer, variando no intervalo entre 0 e 1.
# * <b>Experimento aleatório:</b> É considerado um experimento aleatório tudo aquilo que em condições de teste semelhantes possui resultados imprevisíveis, como por exemplo o arremessar de dados e moedas. Nunca temos certeza absoluta de qual lado irá cair, com isto tudo o que é possível realizar são inferências de quais possibilidades podem ocorrer a partir de "n" tentativas.
# * <b>Espaço amostral (Ω):</b>Contêm todos os resultados possíveis do experimento.
# * <b>Evento:</b> Eventos são conjuntos de resultados que geralmente são representados através de uma letra maiúscula, por exemplo, imagine um dado.
#     * <b>A: Obter um número par.</b> -> É um evento possível, porém incerto.
#     * <b>B: Obter um número ímpar.</b> -> É um evento possível, porém incerto.
#     * <b>C: Obter um número entre 1 e 6</b> -> Considerado um evento certo, pois é garantido que o dado de seis lados caia entre 1 e 6.
#     * <b>D: Obter o número 7</b> -> Considerado um evento impossível pelo fato dos dados não terem sete lados. Logo recebe recebe 0 como resposta.
# * <b>Evento determinístico ou aleatório:</b> O determinístico é aquele evento que sempre ocorrerá se circunstâncias específicas forem preenchidas, como por exemplo um ovo na condição específica flutuar na agua, ou um botão. Enquanto o aleatório é aquele que não podemos ter certeza do resultado, como o arremessar de um dado ou moeda.
#
#
# <hr>
#
# <b><h4>Eventos</h4></b>
#
# Temos alguns tipos de evento que valem a pena serem mencionados como por exemplo:
#
# * <b>Evento elementar:</b> Contêm apenas um resultado  (ω) <- Este símbolo é um Omega minúsculo, e representa um dos resultados do espaço amostral.
# * <b>Evento composto:</b> Contêm múltiplos resultados.
# * <b>Evento certo:</b> Representado pelo símbolo de omega maiusculo, onde basicamente fala que sempre estará dentro dos resultados do espaço amostral. (Ω)
# * <b>Evento impossível:</b> Representado pelo símbolo de conjunto nulo/vazio (∅), este evento não irá ocorrer.
#
# Falando um pouco sobre operações com estes eventos temos:
# * <b>União (∪) -> A ∪ B:</b> Poderia ser dito como, qual a probabilidade do evento A ou B ocorrerem.
#     * A sua fórmula é: P(A u B) = P(A) + P(B) - P(A n B)
#     * Em casos onde não há intersecção entre A e B, a fórmula se torna P(A u B) = P(A) + P(B)
#
# * <b>Interseção (∩) -> A ∩ B:</b> A e B ocorrem simultaneamente
# * <b>Complementar (Aᶜ) -> Aᶜ:</b> A não ocorre.
#
# <hr>
